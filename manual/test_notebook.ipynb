# %%
print("Hello world!")
# Out:
# Hello world!

# %%
import pandas as pd

# %%
pd.read_csv("../data/raw/MicroarrayExpression.csv", index_col=0, header=None)
# Out:
#               1         2         3         4         5         6         7    \
# 0
# 1058685  3.615792  2.138074  2.480542  2.964972  2.679803  1.856238  2.280435
# 1058684  1.574380  1.687217  1.975735  2.089475  1.912586  1.601138  1.626724
# 1058683  1.596431  1.948371  2.191910  2.224042  2.223798  1.557563  1.940634
# 1058682  4.482883  6.606044  5.261559  4.013277  5.600743  5.624775  4.552105
# 1058681  6.291312  8.149890  7.948218  6.964453  8.682156  7.753634  7.462767
# ...           ...       ...       ...       ...       ...       ...       ...
# 1071207  4.987220  4.145995  4.589687  3.561543  3.304363  6.798598  3.590037
# 1071208  4.784908  5.774458  7.344428  6.931995  7.082742  6.873591  6.432648
# 1071209  1.600835  2.499161  3.375202  2.670347  2.907766  1.800546  3.780652
# 1071210  5.309298  6.664290  4.930464  6.747977  8.973160  6.940977  5.484037
# 1071211  5.143094  5.971592  6.625777  5.048890  4.977652  5.527491  5.581687
#
# ...

# %%
probes = pd.read_csv("../data/raw/Probes.csv", index_col="probe_id")
probes.head()
# Out:
#                       probe_name  gene_id gene_symbol  \
# probe_id
# 1058685              A_23_P20713      729         C8G
# 1058684   CUST_15185_PI416261804      731          C9
# 1058683             A_32_P203917      731          C9
# 1058682             A_23_P138819      736      MRPL49
# 1058681             A_24_P232500      736      MRPL49
#
#                                           gene_name  entrez_id chromosome
# probe_id
# 1058685   complement component 8, gamma polypeptide      733.0          9
# 1058684                      complement component 9      735.0          5
# 1058683                      complement component 9      735.0          5
# 1058682         mitochondrial ribosomal protein L49      740.0         11
# 1058681         mitochondrial ribosomal protein L49      740.0         11

# %%
print(probes.value_counts("chromosome"))
# Out:
# chromosome
# 1        4909
# 19       3117
# 2        3085
# 11       2992
# 17       2793
# 6        2641
# 3        2593
# 12       2499
# 7        2287
# 5        2168
# 4        1993
# X        1962
# 16       1954
# 9        1894
# 10       1832
# 8        1669
# 14       1478
# 15       1475
# 20       1301
# 22       1105
# 13        852
# 18        697
# 21        645
# Y         126
# X|Y        44
# Un         39
# 18|Un       2
# 3|Un        1
# 17|Un       1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(probes["chromosome"].value_counts().index, probes["chromosome"].value_counts().values)
# Out:
# <BarContainer object of 29 artists>
